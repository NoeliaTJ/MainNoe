# %%
mensaje = "mensaje"
# tambien podria ser #mensaje = []
# esto significa que esta vacío

if mensaje:
    print("Hay mensaje")
else:
    print("Esta vacio")
# Out:
# Hay mensaje

# %%
# Funcion
print()
input()

Def saludar():


# Método
lista = [1, 2, 3, 4]

Lista_ampliada = lista.append(5)


# Parámetro
