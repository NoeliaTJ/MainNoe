# %%
# Ejemplo de clase
#1. Crea una lista con 4 de tus películas favoritas
lista_peliculas = ["Street Fighter la última batalla", "El Pianista", "Toda la saga de Mercenarios", "Ponyo en el acantilado"]

# 2. Añade una película al final
lista_peliculas.append("Amor de gata")
print(lista_peliculas)

# 3. Añade una película al principio
lista_peliculas.insert(0, "IronMan")
print(lista_peliculas)
# Out:
# ['Street Fighter la última batalla', 'El Pianista', 'Toda la saga de Mercenarios', 'Ponyo en el acantilado', 'Amor de gata']
# ['IronMan', 'Street Fighter la última batalla', 'El Pianista', 'Toda la saga de Mercenarios', 'Ponyo en el acantilado', 'Amor de gata']

# %%
lista_de_cosas = ["patatacruda", "patataCocida", "Patataalhorno", "miau"]
lista_de_cosas.sort(key=len)
print(lista_de_cosas)
# Out:
# ['miau', 'patatacruda', 'patataCocida', 'Patataalhorno']
