# %%
nombre = "hola"
print(nombre)
# Out:
# hola

# %%
# Define la variable
nombre = "hola"
# Escribe en pantalla el valor de la variable
print(nombre)
# Out:
# hola

# %%
edad = 40
nombre = "Noe"
altura = 1.53

print(f"Mi nombre es {nombre}, tengo {edad} años y mido {altura} metros")
# Out:
# Mi nombre es Noe, tengo 40 años y mido 1.53 metros
